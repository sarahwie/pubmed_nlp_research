# %%
#get num records
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import pickle

# %%
#using this file for our example (on local only)
xml_file = ET.parse('training_set_article.xml')
root = xml_file.getroot()

# %%
#read in pmids
text_file = open("article_replication_PMIDs_list.txt", "r")
pmids = text_file.read().split(',')
print len(pmids)
print type(pmids[0])
# Out:
# 354
# <type 'str'>

# %%
#testing that we got all the records: yes! success.
i = 0
j = 0
k = 0
for record in root.findall('PubmedArticle'):
    #try:
    pmid = record.find('MedlineCitation').find('PMID').text
    if pmid not in pmids:
        print 'Error'
    #    k = k + 1
    #except AttributeError:
        #dont include if no abstract
        #something random to hold place of indent:
    #    print record.find('MedlineCitation').find('PMID').text
    #    print ("Fail:", i)
    #    j = j + 1
    i = i + 1

print i
# Out:
# 354

# %% [markdown]
# ### Convert to Pandas dataframe (title, abstract, mesh terms, label)

# %%
#convert XML subset to pandas dataframe
def iter_docs(author):
    author_attr = author.attrib
    for record in author.findall('PubmedArticle'):
        doc_dict = author_attr.copy()

        title = record.find('MedlineCitation').find('Article').find('ArticleTitle')
        if type(title.text) != str:
            title.text = title.text.encode('utf8')
        doc_dict['title'] = title.text
        pmid = record.find('MedlineCitation').find('PMID').text
        doc_dict['pmid'] = pmid
        
        abstract = ''
        for abst in record.find('MedlineCitation').find('Article').find('Abstract').findall('AbstractText'):
            if abst.text is not None:
                if type(abst.text) != str:
                    abst.text = abst.text.encode('utf8')
                abstract = abstract + abst.text
        doc_dict['abstract'] = abstract
        
        #get MeSH terms as unicode strings to simplify later processing
        meshDescriptor = ''
        meshQualifier = ''
        if record.find('MedlineCitation').find('MeshHeadingList') is not None:
            for mesh in record.find('MedlineCitation').find('MeshHeadingList').findall('MeshHeading'):
                if mesh.find('DescriptorName') is not None:
                    for desc in mesh.findall('DescriptorName'):
                        if meshDescriptor == '':
                            meshDescriptor = desc.text
                        else:
                            meshDescriptor = meshDescriptor + ' ' + desc.text
                if mesh.find('QualifierName') is not None:
                    for qual in mesh.findall('QualifierName'):
                        if meshQualifier == '':
                            meshQualifier = qual.text
                        else:
                            meshQualifier = meshQualifier + ' ' + qual.text
        doc_dict['qualifier_terms'] = meshQualifier
        doc_dict['descriptor_terms'] = meshDescriptor
        
        yield doc_dict
        
df = pd.DataFrame(list(iter_docs(root)))
df = df[['pmid', 'title', 'abstract', 'qualifier_terms', 'descriptor_terms']]

# %%
df
# Out:
#          pmid                                              title  \
# 0    23195993  Gene expression profiles in peripheral blood m...
# 1    25077433  SOX2 is a cancer-specific regulator of tumour ...
# 2    24107601  Imaging and cerebrospinal fluid biomarkers in ...
# 3    24891029  Preliminary evidence of cognitive and brain ab...
# 4    21691448  Obese Adolescents with Type 2 Diabetes Mellitu...
# 5    22765222  Diversity of 5S rRNA genes within individual p...
# 6    24401686  Myoinositol and glutamate complex neurometabol...
# 7    22914093  Antibiotics in early life alter the murine col...
# 8    23426830  Elevated serum anti-Müllerian hormone in adole...
# 9    24344399  Association of obesity-mediated insulin resist...
# 10   22761902  Regression of atherosclerosis is characterized...
# 11   23344457  Bioinformatic analysis of benzo-α-pyrene-induc...
# 12   24444828  α4βδ-GABAARs in the hippocampal CA1 as a bioma...
# 11   Intrauterine growth restriction (IUGR) has bee...
# 12   Anorexia nervosa (AN) is a psychiatric illness...
# 13   Leprosy was the first disease classified accor...
# 14   Adenosine is an endogenous nucleoside that mod...
# 15   Objectives Obesity is on the rise in the US an...
# 16   Lymphoid enhancer-binding factor (LEF)1 is a m...
# 17   Air pollution contributes to acute exacerbatio...
# 18   In adults, obesity has been associated with di...
# 19   Measurement of telomere length currently requi...
# 20   To evaluate the association of risk and age at...
# 21   Pediatric drug development is hampered by biol...
# 22   Although the hypothalamic orexin system is kno...
# 23   Acrolein, an α,β-unsaturated aldehyde and a re...
# 24   To adapt to stresses encountered in stationary...
# 25   'Spice' is an herbal blend that has been repor...
# 26   N-type Ca(2+) channels (CaV2.2) are a nidus fo...
# 27   Alphavirus dogma has long dictated the product...
# 28   Neurofibromatosis type 1 (NF1) results from mu...
# 29   T cells use the αβ TCR to bind peptides presen...
# ..                                                 ...
# 324  It is difficult to reliably detect the earlies...
# 325  The mechanisms by which smoking cessation redu...
# 326  To report the surgical treatment of hypertropi...
# 327  The HeartMate II is the most frequently used l...
# 328  Suicide attempt rates were assessed in 1306 su...
# 329  Cognitive changes related to cancer and its tr...
# 330  There is growing interest in measuring social ...
# 331  Angiosarcoma is an aggressive malignancy with ...
# 332  Because cystic fibrosis can be difficult to di...
# 333  The objective was to evaluate the difference i...
# 334  There is increasing evidence that proton pump ...
# 335  The role of the Alzheimer's Disease Neuroimagi...
# 336  Population-based birth cohorts on asthma and a...
# 337  Underlying the importance of research on the b...
# 338  A 1-year-old male German shorthaired pointer w...
# 339  We report a patient with dysfibrinogenemia tre...
# 340  NGSUtils is a suite of software tools for mani...
# 341  In 2010, Virginia Commonwealth University (VCU...
# 342  There is a fairly consistent, albeit non-unive...
# 343  Rapid magnetic resonance imaging (MRI) acquisi...
# 344  In methylome-wide association studies (MWAS) t...
# 345  It has been recently demonstrated that interle...
# 346  Although most patients with Hodgkin lymphoma (...
# 347  To present a summary of current scientific evi...
# 348  Microbes are readily cultured from epithelial ...
# 349  Autism spectrum disorders, or pervasive develo...
# 350  It is now recognized that a majority of single...
# 351  Juvenile idiopathic arthritis (JIA) is one of ...
# 352  Primary cardiac sarcomas are rare and carry a ...
# 353  This article challenges recent assumptions tha...
#
#                                        qualifier_terms  \
# 0    genetics metabolism epidemiology drug effects ...
# 1    genetics metabolism pathology metabolism patho...
# 2    cerebrospinal fluid genetics radionuclide imag...
# 3            pathology physiopathology physiopathology
# 4
# 5    chemistry classification genetics chemistry ge...
# 6    analogs & derivatives metabolism metabolism me...
# 7    drug effects physiology administration & dosag...
# 8    blood pathology ultrasonography blood ultrason...
# 9    blood analysis anatomy & histology blood blood...
# 10   genetics immunology genetics immunology geneti...
# 11   toxicity methods toxicity metabolism drug effe...
# 12   metabolism analysis chemistry metabolism ultra...
# 13   immunology drug therapy immunology drug effect...
# 14   pharmacology metabolism physiology drug effect...
# 15
# 16   metabolism metabolism metabolism metabolism me...
# 17   genetics metabolism metabolism genetics metabo...
# 18   psychology physiopathology psychology growth &...
# 19   cytology metabolism cytology metabolism method...
# 20   genetics mortality genetics genetics genetics ...
# 21   blood methods methods administration & dosage ...
# 29   Animals Computational Biology HLA-A2 Antigen H...
# ..                                                 ...
# 324  Age Factors Alzheimer Disease Cognition Compar...
# 325  Adult Antihypertensive Agents Atherosclerosis ...
# 326  Adolescent Adult Aged Aged, 80 and over Child ...
# 327  Adult Cohort Studies Echocardiography, Doppler...
# 328  Adult Antipsychotic Agents Bipolar Disorder Fe...
# 329  Adult Aged Antineoplastic Combined Chemotherap...
# 330  Adolescent Antipsychotic Agents Child Child De...
# 331  Adult Aged Aged, 80 and over Female Hemangiosa...
# 332  Algorithms Combined Modality Therapy Cost-Bene...
# 333  Aged Carotid Artery Diseases Chi-Square Distri...
# 334  Adult Aged Aged, 80 and over Bacteremia Clostr...
# 335  Alzheimer Disease Biomarkers Cognition Disorde...
# 336  Asthma Humans Hypersensitivity National Heart,...
# 337  Aging Animals Caloric Restriction Energy Intak...
# 338  Animals Coronary Vessel Anomalies Dog Diseases...
# 339  Adolescent Afibrinogenemia Fibrinogen Hematolo...
# 340  Genomics High-Throughput Nucleotide Sequencing...
# 341  Awards and Prizes Ethics Committees, Research ...
# 342  Aged Aging Antineoplastic Agents Breast Neopla...
# 343  Acceleration Image Processing, Computer-Assist...
# 344  Algorithms DNA Methylation Genetic Association...
# 345  Acute Disease Anti-Inflammatory Agents, Non-St...
# 346  Antibodies, Monoclonal Antigens, CD30 Antineop...
# 347  Animals Anticonvulsants Brain Cannabidiol Cann...
# 348  Humans Inflammation Lung Lung Diseases Metagen...
# 349  Adult Animals Central Nervous System Agents Ch...
# 350  Consensus Coronary Circulation Heart Bypass, R...
# 351  Anti-Inflammatory Agents, Non-Steroidal Antirh...
# 352  Administration, Oral Antineoplastic Agents, Ph...
# 353  Benzhydryl Compounds Central Nervous System St...
#
# [354 rows x 5 columns]

# %%
df.iloc[0]['descriptor_terms']
# Out:
# 'Adult Asian Continental Ancestry Group Biomarkers Case-Control Studies China Gene Expression Profiling Humans Leukocytes, Mononuclear Male Metallurgy Middle Aged Nickel Occupational Diseases Occupational Exposure Oligonucleotide Array Sequence Analysis Prognosis RNA, Messenger Real-Time Polymerase Chain Reaction Reverse Transcriptase Polymerase Chain Reaction Risk Factors'

# %% [markdown]
# ### Add labels to dataframe from Excel file

# %%
#read in Excel file-- didn't work
#labs = pd.read_excel('/home/sarahwie/Documents/pubmed-nlp-research/article_replication/data_files/TrainingSet.xlsx')

# %%
#do manually instead
labs = pd.read_csv('/home/sarahwie/Documents/pubmed-nlp-research/article_replication/data_files/labels.csv')

# %%
print labs
# Out:
#          pmid  label
# 0    23195993     T0
# 1    25077433     T0
# 2    24107601     T0
# 3    24891029     T0
# 4    21691448     T0
# 5    22765222     T0
# 6    24401686     T0
# 7    22914093     T0
# 8    23426830     T0
# 9    24344399     T0
# 10   22761902     T0
# 11   23344457     T0
# 12   24444828     T0
# 13   22527432     T0
# 14   22311477     T0
# 15   22021878     T0
# 16   21527502     T0
# 17   23455502     T0
# 18   21350433     T0
# 19   23661059     T0
# 20   22869155     T0
# 21   23595360     T0
# 22   22554617     T0
# 23   24286176     T0
# 24   24520065     T0
# 25   21333643     T0
# 26   22891239     T0
# 27   23720714     T0
# 28   20160346     T0
# 29   22611242     T0
# ..        ...    ...
# 324  24556849  T3/T4
# 325  22496918  T3/T4
# 326  20603056  T3/T4
# 327  23311405  T3/T4
# 328  22871534  T3/T4
# 329  22613170  T3/T4
# 330  23104617  T3/T4
# 331  23428947  T3/T4
# 332  22291119  T3/T4
# 333  24321266  T3/T4
# 334  22966967  T3/T4
# 335  20451875     TX
# 336  24636091     TX
# 337  22290875     TX
# 338  24485987     TX
# 339  23129109     TX
# 340  23314324     TX
# 341  23960269     TX
# 342  24331192     TX
# 343  23387767     TX
# 344  23452721     TX
# 345  23319019     TX
# 346  24287071     TX
# 347  24854329     TX
# 348  24460444     TX
# 349  20470188     TX
# 350  23510301     TX
# 351  23605168     TX
# 352  23652877     TX
# 353  21561522     TX
#
# [354 rows x 2 columns]

# %%
#append labels
df['label'] = 'A'
for i in range(len(df)):
    #get true label value from labels
    pmid = df.iloc[i]['pmid']
    df.set_value(i, 'label', labs['label'][i])

# %%
df
# Out:
#          pmid                                              title  \
# 0    23195993  Gene expression profiles in peripheral blood m...
# 1    25077433  SOX2 is a cancer-specific regulator of tumour ...
# 2    24107601  Imaging and cerebrospinal fluid biomarkers in ...
# 3    24891029  Preliminary evidence of cognitive and brain ab...
# 4    21691448  Obese Adolescents with Type 2 Diabetes Mellitu...
# 5    22765222  Diversity of 5S rRNA genes within individual p...
# 6    24401686  Myoinositol and glutamate complex neurometabol...
# 7    22914093  Antibiotics in early life alter the murine col...
# 8    23426830  Elevated serum anti-Müllerian hormone in adole...
# 9    24344399  Association of obesity-mediated insulin resist...
# 10   22761902  Regression of atherosclerosis is characterized...
# 11   23344457  Bioinformatic analysis of benzo-α-pyrene-induc...
# 12   24444828  α4βδ-GABAARs in the hippocampal CA1 as a bioma...
# 13   22527432  Lessons of leprosy: the emergence of TH17 cyto...
# 14   22311477  Adenosine A1 receptor regulates osteoclast for...
# 15   22021878  Obesity, orbitofrontal structure and function ...
# 16   21527502  LEF1 identifies androgen-independent epitheliu...
# 17   23455502  MicroRNA-375 regulation of thymic stromal lymp...
# 18   21350433  Disinhibited eating in obese adolescents is as...
# 19   23661059  Robust measurement of telomere length in singl...
# 20   22869155  Comprehensive search for Alzheimer disease sus...
# 21   23595360  Assessment of juvenile pigs to serve as human ...
# 22   22554617  Orexin 1 receptors are a novel target to modul...
# 23   24286176  Neuroprotective role of hydralazine in rat spi...
# 24   24520065  Haemophilus ducreyi Hfq contributes to virulen...
# 25   21333643  CP47,497-C8 and JWH073, commonly found in 'Spi...
# 26   22891239  Inhibition of transmitter release and attenuat...
# 27   23720714  Functional characterization of the alphavirus ...
# 28   20160346  Genetic and cellular evidence of vascular infl...
# 29   22611242  Cutting edge: Evidence for a dynamically drive...
# ..        ...                                                ...
# 324  24556849  Emergence of mild cognitive impairment in late...
# 325  22496918  Effects of smoking and cessation on subclinica...
# 326  20603056  Surgical management of clinically significant ...
# 327  23311405  Effects of the HeartMate II left ventricular a...
# 328  22871534  Suicide attempts in veterans with bipolar diso...
# 329  22613170  Frontal gray matter reduction after breast can...
# 330  23104617  Brief Report: social disability in autism spec...
# 331  23428947  Angiosarcoma outcomes and prognostic factors: ...
# 332  22291119  A decision-tree approach to cost comparison of...
# 333  24321266  Carotid endarterectomy national trends over a ...
# 334  22966967  Proton pump inhibitors are associated with a h...
# 335  20451875  Alzheimer's Disease Neuroimaging Initiative bi...
# 336  24636091  Birth cohorts in asthma and allergic diseases:...
# 337  22290875  The caloric restriction paradigm: implications...
# 338  24485987  Advanced multimodality imaging of an anomalous...
# 339  23129109  Use of purified fibrinogen concentrate for dys...
# 340  23314324  NGSUtils: a software suite for analyzing and m...
# 341  23960269  Reorganizing the General Clinical Research Cen...
# 342  24331192  Cognitive effects of cancer and its treatments...
# 343  23387767  Highly accelerated projection imaging with coi...
# 344  23452721  MethylPCA: a toolkit to control for confounder...
# 345  23319019  Mechanistic aspects of inflammation and clinic...
# 346  24287071  Customized targeted therapy in Hodgkin lymphom...
# 347  24854329  Cannabidiol: pharmacology and potential therap...
# 348  24460444  Lung microbiome for clinicians. New discoverie...
# 349  20470188  Emerging drugs for the treatment of symptoms a...
# 350  23510301  Mechanical support as failure intervention in ...
# 351  23605168  Update on the treatment of juvenile idiopathic...
# 352  23652877  Significant response to oral Etoposide in the ...
# 353  21561522  Reining in the pharmacological enhancement tra...
#
#                                               abstract  \
# 0    Occupational exposure to nickel (Ni) is associ...
# 1    Although the principles that balance stem cell...
# 2    The pathophysiological process of Alzheimer's ...
# 3    To ascertain whether pediatric obesity without...
# 4    The rates of type 2 diabetes (T2DM) continue t...
# 5    We examined intragenomic variation of paralogo...
# 6    To obtain quantitative neurometabolite measure...
# 7    Antibiotics administered in low doses have bee...
# 8    Serum anti-Müllerian hormone (AMH) is linked t...
# 9    The hypothalamus is important in hunger and me...
# 10   We have developed a mouse model of atheroscler...
# 11   Intrauterine growth restriction (IUGR) has bee...
# 12   Anorexia nervosa (AN) is a psychiatric illness...
# 13   Leprosy was the first disease classified accor...
# 14   Adenosine is an endogenous nucleoside that mod...
# 15   Objectives Obesity is on the rise in the US an...
# 16   Lymphoid enhancer-binding factor (LEF)1 is a m...
# 17   Air pollution contributes to acute exacerbatio...
# 18   In adults, obesity has been associated with di...
# 19   Measurement of telomere length currently requi...
# 20   To evaluate the association of risk and age at...
# 21   Pediatric drug development is hampered by biol...
# 22   Although the hypothalamic orexin system is kno...
# 23   Acrolein, an α,β-unsaturated aldehyde and a re...
# 24   To adapt to stresses encountered in stationary...
# 25   'Spice' is an herbal blend that has been repor...
# 26   N-type Ca(2+) channels (CaV2.2) are a nidus fo...
# 27   Alphavirus dogma has long dictated the product...
# 28   Neurofibromatosis type 1 (NF1) results from mu...
# 29   T cells use the αβ TCR to bind peptides presen...
# ..                                                 ...
# 324  It is difficult to reliably detect the earlies...
# 325  The mechanisms by which smoking cessation redu...
# 326  To report the surgical treatment of hypertropi...
# 327  The HeartMate II is the most frequently used l...
# 328  Suicide attempt rates were assessed in 1306 su...
# 329  Cognitive changes related to cancer and its tr...
# 330  There is growing interest in measuring social ...
# 331  Angiosarcoma is an aggressive malignancy with ...
# 332  Because cystic fibrosis can be difficult to di...
# 333  The objective was to evaluate the difference i...
# 334  There is increasing evidence that proton pump ...
# 335  The role of the Alzheimer's Disease Neuroimagi...
# 336  Population-based birth cohorts on asthma and a...
# 337  Underlying the importance of research on the b...
# 338  A 1-year-old male German shorthaired pointer w...
# 339  We report a patient with dysfibrinogenemia tre...
# 340  NGSUtils is a suite of software tools for mani...
# 341  In 2010, Virginia Commonwealth University (VCU...
# 342  There is a fairly consistent, albeit non-unive...
# 343  Rapid magnetic resonance imaging (MRI) acquisi...
# 344  In methylome-wide association studies (MWAS) t...
# 345  It has been recently demonstrated that interle...
# 346  Although most patients with Hodgkin lymphoma (...
# 347  To present a summary of current scientific evi...
# 348  Microbes are readily cultured from epithelial ...
# 349  Autism spectrum disorders, or pervasive develo...
# 350  It is now recognized that a majority of single...
# 351  Juvenile idiopathic arthritis (JIA) is one of ...
# 352  Primary cardiac sarcomas are rare and carry a ...
# 353  This article challenges recent assumptions tha...
#
#                                        qualifier_terms  \
# 0    genetics metabolism epidemiology drug effects ...
# 1    genetics metabolism pathology metabolism patho...
# 2    cerebrospinal fluid genetics radionuclide imag...
# 3            pathology physiopathology physiopathology
# 4
# 5    chemistry classification genetics chemistry ge...
# 6    analogs & derivatives metabolism metabolism me...
# 7    drug effects physiology administration & dosag...
# 8    blood pathology ultrasonography blood ultrason...
# 9    blood analysis anatomy & histology blood blood...
# 10   genetics immunology genetics immunology geneti...
# 11   toxicity methods toxicity metabolism drug effe...
# 12   metabolism analysis chemistry metabolism ultra...
# 13   immunology drug therapy immunology drug effect...
# 14   pharmacology metabolism physiology drug effect...
# 15
# 16   metabolism metabolism metabolism metabolism me...
# 17   genetics metabolism metabolism genetics metabo...
# 18   psychology physiopathology psychology growth &...
# 19   cytology metabolism cytology metabolism method...
# 20   genetics mortality genetics genetics genetics ...
# 21   blood methods methods administration & dosage ...
# 22   drug effects physiology drug effects physiolog...
# 23   metabolism drug effects drug therapy pathology...
# 24   microbiology pathology genetics growth & devel...
# 25   chemistry pharmacology chemistry pharmacology ...
# 26   drug therapy genetics metabolism pathology gen...
# 27   mortality pathology virology genetics pathogen...
# 28   metabolism pathology metabolism pathology meta...
# 29   chemistry immunology immunology chemistry immu...
# ..                                                 ...
# 324  prevention & control diagnosis etiology psycho...
# 325  therapeutic use drug therapy epidemiology ultr...
# 326  complications surgery surgery methods complica...
# 327  methods mortality physiopathology surgery ultr...
# 328  therapeutic use drug therapy therapeutic use p...
# 329  adverse effects therapeutic use pathology drug...
# 330  therapeutic use drug therapy psychology therap...
# 331  mortality pathology therapy mortality patholog...
# 332  diagnosis economics genetics genetics economic...
# 333  diagnosis mortality surgery adverse effects mo...
# 334  chemically induced chemically induced adverse ...
# 335  diagnosis genetics cerebrospinal fluid metabol...
# 336              diagnosis etiology diagnosis etiology
# 337                              physiology physiology
# 338  radiography surgery veterinary diagnosis surge...
# 339  drug therapy analysis metabolism therapeutic u...
# 340                                            methods
# 341  economics economics organization & administration
# 342  psychology adverse effects complications psych...
# 343                                            methods
# 344
# 345  therapeutic use drug therapy physiopathology p...
# 346  pharmacology therapeutic use antagonists & inh...
# 347  pharmacology therapeutic use drug effects phar...
# 348    immunology microbiology immunology microbiology
# 349  adverse effects pharmacology therapeutic use d...
# 350  adverse effects diagnosis physiopathology surg...
# 342  Aged Aging Antineoplastic Agents Breast Neopla...     TX
# 343  Acceleration Image Processing, Computer-Assist...     TX
# 344  Algorithms DNA Methylation Genetic Association...     TX
# 345  Acute Disease Anti-Inflammatory Agents, Non-St...     TX
# 346  Antibodies, Monoclonal Antigens, CD30 Antineop...     TX
# 347  Animals Anticonvulsants Brain Cannabidiol Cann...     TX
# 348  Humans Inflammation Lung Lung Diseases Metagen...     TX
# 349  Adult Animals Central Nervous System Agents Ch...     TX
# 350  Consensus Coronary Circulation Heart Bypass, R...     TX
# 351  Anti-Inflammatory Agents, Non-Steroidal Antirh...     TX
# 352  Administration, Oral Antineoplastic Agents, Ph...     TX
# 353  Benzhydryl Compounds Central Nervous System St...     TX
#
# [354 rows x 6 columns]

# %%
print len(np.where(df['label']=='TX')[0])
print len(np.where(df['label']=='T0')[0])
print len(np.where(df['label']=='T1/T2')[0])
print len(np.where(df['label']=='T3/T4')[0])
#counts match
# Out:
# 30
# 162
# 67
# 94

# %%
pickle.dump(df, open('/home/sarahwie/Documents/pubmed-nlp-research/article_replication/df.p', 'wb'))

# %% [markdown]
# ### Construct pandas dataframe only using abstracts (no titles or mesh terms)

# %%
#convert XML subset to pandas dataframe
def iter_docs(author):
    author_attr = author.attrib
    for record in author.findall('PubmedArticle'):
        doc_dict = author_attr.copy()

        title = record.find('MedlineCitation').find('Article').find('ArticleTitle').text
        doc_dict['title'] = title
        pmid = record.find('MedlineCitation').find('PMID').text
        doc_dict['pmid'] = pmid
        
        abstract = ''
        for abst in record.find('MedlineCitation').find('Article').find('Abstract').findall('AbstractText'):
            if abst.text is not None:
                if type(abst.text) != str:
                    abst.text = abst.text.encode('utf8')
                abstract = abstract + abst.text
        doc_dict['abstract'] = abstract
        
        #get MeSH terms as unicode strings to simplify later processing
        meshDescriptor = ''
        meshQualifier = ''
        if record.find('MedlineCitation').find('MeshHeadingList') is not None:
            for mesh in record.find('MedlineCitation').find('MeshHeadingList').findall('MeshHeading'):
                if mesh.find('DescriptorName') is not None:
                    for desc in mesh.findall('DescriptorName'):
                        if meshDescriptor == '':
                            meshDescriptor = desc.text
                        else:
                            meshDescriptor = meshDescriptor + ' ' + desc.text
                if mesh.find('QualifierName') is not None:
                    for qual in mesh.findall('QualifierName'):
                        if meshQualifier == '':
                            meshQualifier = qual.text
                        else:
                            meshQualifier = meshQualifier + ' ' + qual.text
        doc_dict['qualifier_terms'] = meshQualifier
        doc_dict['descriptor_terms'] = meshDescriptor
        
        yield doc_dict
        
df_absonly = pd.DataFrame(list(iter_docs(root)))
df_absonly = df_absonly[['pmid', 'title', 'abstract', 'qualifier_terms', 'descriptor_terms']]

# %%
#append labels
df_absonly['label'] = 'A'
for i in range(len(df_absonly)):
    #get true label value from labels
    pmid = df_absonly.iloc[i]['pmid']
    df_absonly.set_value(i, 'label', labs['label'][i])

# %%
pickle.dump(df_absonly, open('/home/sarahwie/Documents/pubmed-nlp-research/article_replication/df_absOnly.p', 'wb'))

# %% [markdown]
# ## Get External Validation set

# %%
#decided to use the same training/test set and just use a subset for validation.
#The actual validation set is the records that were scored really highly by their model. 
#So don't think we can compare performance scores for those.
